# %% [markdown]
# # Welcome to the Jupyter Notebook describing BioTechTopics!  Here, I will show a brief introduction to the application.

# %% [markdown]
# ## Here we will import the Topics class and create an instance t.
# This will read the corpus using pandas, train a matrix representation of the corpus using CountVectorizer, then perform Latent Dirichlet Allocation.  It's done when "Topics instance ready" is printed.

# %%
from BioTechTopics import Topics
t=Topics()
# Out:
# Reading corpus
# Corpus contains 100 unique files
#
# Training Count Vectorizer
# Done training after 3.20076990128 seconds
#
# Training LDA probability distributions
# Done training after 1.12569117546 seconds
# Topics instance ready

# %% [markdown]
# ## Now we can show Word Cloud representations of the corpus!

# %%
t.showWordCloud(2)
